# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | comodoro rivadavia
# Processing Record 9 of Set 1 | saint-pierre
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | nikolayevskaya
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | puro
# Processing Record 18 of Set 1 | great falls
# Processing Record 19 of Set 1 | melfi
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | rocha
# Processing Record 23 of Set 1 | we
# City not found. Skipping...
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | salta
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | okha
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | binucayan
# Processing Record 32 of Set 1 | lasa
# Processing Record 33 of Set 1 | beringovskiy
# Processing Record 34 of Set 1 | asau
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | quatre cocos
# Processing Record 37 of Set 1 | codrington
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | rio de jesus
# Processing Record 40 of Set 1 | klyuchi
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | aramil
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | port lincoln
# Processing Record 49 of Set 1 | cuamba
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | saint anthony
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | batsfjord
# Processing Record 5 of Set 2 | concarneau
# Processing Record 6 of Set 2 | rafaela
# Processing Record 7 of Set 2 | ghauspur
# Processing Record 8 of Set 2 | labuan
# Processing Record 9 of Set 2 | bathsheba
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | zastron
# Processing Record 13 of Set 2 | katsuura
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | ballina
# Processing Record 16 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 2 | andenes
# Processing Record 18 of Set 2 | husavik
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | beyneu
# Processing Record 22 of Set 2 | tateyama
# Processing Record 23 of Set 2 | gamba
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | poplar bluff
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | sunagawa
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | sambava
# Processing Record 30 of Set 2 | mayo
# Processing Record 31 of Set 2 | makkaveyevo
# Processing Record 32 of Set 2 | bandrele
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | cockburn town
# Processing Record 35 of Set 2 | tura
# Processing Record 36 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 2 | gat
# Processing Record 38 of Set 2 | loiza
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | olinda
# Processing Record 41 of Set 2 | mokhotlong
# Processing Record 42 of Set 2 | tooele
# Processing Record 43 of Set 2 | acajutla
# Processing Record 44 of Set 2 | hobyo
# Processing Record 45 of Set 2 | roma
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | taltal
# Processing Record 50 of Set 2 | dombarovskiy
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | noumea
# Processing Record 4 of Set 3 | caravelas
# Processing Record 5 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 3 | anshun
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | champerico
# Processing Record 9 of Set 3 | sorong
# Processing Record 10 of Set 3 | hofn
# Processing Record 11 of Set 3 | deputatskiy
# Processing Record 12 of Set 3 | samoylovka
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | akhmim
# Processing Record 17 of Set 3 | mfou
# Processing Record 18 of Set 3 | nouadhibou
# Processing Record 19 of Set 3 | airai
# Processing Record 20 of Set 3 | aguimes
# Processing Record 21 of Set 3 | albany
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | punta arenas
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | leningradskiy
# Processing Record 26 of Set 3 | blois
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | bluff
# Processing Record 29 of Set 3 | pisco
# Processing Record 30 of Set 3 | alice springs
# Processing Record 31 of Set 3 | pitimbu
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | sangar
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | acaponeta
# Processing Record 37 of Set 3 | zhezkazgan
# Processing Record 38 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 3 | kaeo
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | mehamn
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | atuona
# Processing Record 44 of Set 3 | lanxi
# Processing Record 45 of Set 3 | atikokan
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 3 | vesele
# Processing Record 49 of Set 3 | kaseda
# Processing Record 50 of Set 3 | ormara
# Processing Record 1 of Set 4 | labuhan
# Processing Record 2 of Set 4 | akyab
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | puerto del rosario
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 4 | collie
# Processing Record 8 of Set 4 | sarny
# Processing Record 9 of Set 4 | souillac
# Processing Record 10 of Set 4 | narsaq
# Processing Record 11 of Set 4 | esterhazy
# Processing Record 12 of Set 4 | zunyi
# Processing Record 13 of Set 4 | severomuysk
# Processing Record 14 of Set 4 | longyan
# Processing Record 15 of Set 4 | mirzapur
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | lavrentiya
# Processing Record 19 of Set 4 | butaritari
# Processing Record 20 of Set 4 | mutuipe
# Processing Record 21 of Set 4 | constitucion
# Processing Record 22 of Set 4 | tasiilaq
# Processing Record 23 of Set 4 | praia da vitoria
# Processing Record 24 of Set 4 | myanaung
# Processing Record 25 of Set 4 | simplicio mendes
# Processing Record 26 of Set 4 | hami
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | richards bay
# Processing Record 29 of Set 4 | north bend
# Processing Record 30 of Set 4 | margate
# Processing Record 31 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | nikolskoye
# Processing Record 33 of Set 4 | kudahuvadhoo
# Processing Record 34 of Set 4 | khandyga
# Processing Record 35 of Set 4 | nome
# Processing Record 36 of Set 4 | kamennomostskiy
# Processing Record 37 of Set 4 | pacifica
# Processing Record 38 of Set 4 | soledade
# Processing Record 39 of Set 4 | hithadhoo
# Processing Record 40 of Set 4 | alenquer
# Processing Record 41 of Set 4 | altamont
# Processing Record 42 of Set 4 | yueyang
# Processing Record 43 of Set 4 | bermeo
# Processing Record 44 of Set 4 | kushima
# Processing Record 45 of Set 4 | distraccion
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | johnshaven
# Processing Record 50 of Set 4 | wladyslawowo
# Processing Record 1 of Set 5 | katangli
# Processing Record 2 of Set 5 | puerto ayora
# Processing Record 3 of Set 5 | colares
# Processing Record 4 of Set 5 | kaitangata
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | ust-ishim
# Processing Record 7 of Set 5 | dali
# Processing Record 8 of Set 5 | darhan
# Processing Record 9 of Set 5 | kouroussa
# Processing Record 10 of Set 5 | waterloo
# Processing Record 11 of Set 5 | poum
# Processing Record 12 of Set 5 | omboue
# Processing Record 13 of Set 5 | bang saphan
# Processing Record 14 of Set 5 | alofi
# Processing Record 15 of Set 5 | erdaojiang
# Processing Record 16 of Set 5 | saint-joseph
# Processing Record 17 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 5 | limbe
# Processing Record 21 of Set 5 | takoradi
# Processing Record 22 of Set 5 | koulikoro
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | rudnya
# Processing Record 25 of Set 5 | deer lake
# Processing Record 26 of Set 5 | hasaki
# Processing Record 27 of Set 5 | farafenni
# Processing Record 28 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 5 | batagay
# Processing Record 30 of Set 5 | kahului
# Processing Record 31 of Set 5 | marsh harbour
# Processing Record 32 of Set 5 | dujuma
# City not found. Skipping...
# Processing Record 33 of Set 5 | mazatlan
# Processing Record 34 of Set 5 | aitape
# Processing Record 35 of Set 5 | naze
# Processing Record 36 of Set 5 | ulaanbaatar
# Processing Record 37 of Set 5 | cabedelo
# Processing Record 38 of Set 5 | abu samrah
# Processing Record 39 of Set 5 | svetlyy
# Processing Record 40 of Set 5 | iberia
# Processing Record 41 of Set 5 | sinnamary
# Processing Record 42 of Set 5 | mahon
# Processing Record 43 of Set 5 | poronaysk
# Processing Record 44 of Set 5 | emporia
# Processing Record 45 of Set 5 | kiama
# Processing Record 46 of Set 5 | paamiut
# Processing Record 47 of Set 5 | port macquarie
# Processing Record 48 of Set 5 | kaisiadorys
# Processing Record 49 of Set 5 | sim
# Processing Record 50 of Set 5 | bethel
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | mount isa
# Processing Record 3 of Set 6 | faya
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 6 | byron bay
# Processing Record 7 of Set 6 | ilhabela
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | kjollefjord
# Processing Record 10 of Set 6 | point pedro
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | dunedin
# Processing Record 13 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 14 of Set 6 | charagua
# Processing Record 15 of Set 6 | pangnirtung
# Processing Record 16 of Set 6 | mastic beach
# Processing Record 17 of Set 6 | havre-saint-pierre
# Processing Record 18 of Set 6 | henties bay
# Processing Record 19 of Set 6 | puerto colombia
# Processing Record 20 of Set 6 | adrar
# Processing Record 21 of Set 6 | faanui
# Processing Record 22 of Set 6 | bitung
# Processing Record 23 of Set 6 | nishihara
# Processing Record 24 of Set 6 | tabou
# Processing Record 25 of Set 6 | carutapera
# Processing Record 26 of Set 6 | montes altos
# Processing Record 27 of Set 6 | sitka
# Processing Record 28 of Set 6 | lexington
# Processing Record 29 of Set 6 | mokolo
# Processing Record 30 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 6 | yenagoa
# Processing Record 32 of Set 6 | pevek
# Processing Record 33 of Set 6 | macenta
# Processing Record 34 of Set 6 | prattville
# Processing Record 35 of Set 6 | sakaiminato
# Processing Record 36 of Set 6 | moranbah
# Processing Record 37 of Set 6 | saint-georges
# Processing Record 38 of Set 6 | hovd
# Processing Record 39 of Set 6 | pangody
# Processing Record 40 of Set 6 | yar-sale
# Processing Record 41 of Set 6 | alekseyevsk
# Processing Record 42 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 43 of Set 6 | muli
# Processing Record 44 of Set 6 | khani
# Processing Record 45 of Set 6 | korla
# Processing Record 46 of Set 6 | pangkalanbuun
# Processing Record 47 of Set 6 | sobolevo
# Processing Record 48 of Set 6 | hamilton
# Processing Record 49 of Set 6 | lahij
# Processing Record 50 of Set 6 | urucui
# Processing Record 1 of Set 7 | kuusamo
# Processing Record 2 of Set 7 | ouro branco
# Processing Record 3 of Set 7 | volkermarkt
# City not found. Skipping...
# Processing Record 4 of Set 7 | vaitape
# Processing Record 5 of Set 7 | nantucket
# Processing Record 6 of Set 7 | hasilpur
# Processing Record 7 of Set 7 | srednekolymsk
# Processing Record 8 of Set 7 | necochea
# Processing Record 9 of Set 7 | xuddur
# Processing Record 10 of Set 7 | epe
# Processing Record 11 of Set 7 | isangel
# Processing Record 12 of Set 7 | turukhansk
# Processing Record 13 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 7 | rio grande
# Processing Record 15 of Set 7 | kushnarenkovo
# Processing Record 16 of Set 7 | muros
# Processing Record 17 of Set 7 | kenora
# Processing Record 18 of Set 7 | grand gaube
# Processing Record 19 of Set 7 | price
# Processing Record 20 of Set 7 | diu
# Processing Record 21 of Set 7 | lagunas
# Processing Record 22 of Set 7 | college
# Processing Record 23 of Set 7 | copiapo
# Processing Record 24 of Set 7 | ostrovnoy
# Processing Record 25 of Set 7 | wazzan
# City not found. Skipping...
# Processing Record 26 of Set 7 | sechelt
# Processing Record 27 of Set 7 | mackay
# Processing Record 28 of Set 7 | santa maria del oro
# Processing Record 29 of Set 7 | cidreira
# Processing Record 30 of Set 7 | holland
# Processing Record 31 of Set 7 | meadow lake
# Processing Record 32 of Set 7 | guadalupe y calvo
# Processing Record 33 of Set 7 | morristown
# Processing Record 34 of Set 7 | venado tuerto
# Processing Record 35 of Set 7 | sawasawa
# City not found. Skipping...
# Processing Record 36 of Set 7 | vikulovo
# Processing Record 37 of Set 7 | plettenberg bay
# Processing Record 38 of Set 7 | ternovka
# Processing Record 39 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 40 of Set 7 | kopavogur
# Processing Record 41 of Set 7 | potsdam
# Processing Record 42 of Set 7 | komsomolskiy
# Processing Record 43 of Set 7 | westport
# Processing Record 44 of Set 7 | riyadh
# Processing Record 45 of Set 7 | klyuchevskiy
# Processing Record 46 of Set 7 | kaniama
# Processing Record 47 of Set 7 | aksarka
# Processing Record 48 of Set 7 | lompoc
# Processing Record 49 of Set 7 | belyy yar
# Processing Record 50 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 2 of Set 8 | puerto escondido
# Processing Record 3 of Set 8 | talnakh
# Processing Record 4 of Set 8 | san quintin
# Processing Record 5 of Set 8 | victoria
# Processing Record 6 of Set 8 | reyes
# Processing Record 7 of Set 8 | willmar
# Processing Record 8 of Set 8 | saskylakh
# Processing Record 9 of Set 8 | qaqortoq
# Processing Record 10 of Set 8 | hervey bay
# Processing Record 11 of Set 8 | touros
# Processing Record 12 of Set 8 | bayir
# Processing Record 13 of Set 8 | yarensk
# Processing Record 14 of Set 8 | acapulco
# Processing Record 15 of Set 8 | kapustin yar-1
# City not found. Skipping...
# Processing Record 16 of Set 8 | taoudenni
# Processing Record 17 of Set 8 | ponta delgada
# Processing Record 18 of Set 8 | jinxiang
# Processing Record 19 of Set 8 | road town
# Processing Record 20 of Set 8 | torbay
# Processing Record 21 of Set 8 | sorland
# Processing Record 22 of Set 8 | araouane
# Processing Record 23 of Set 8 | cabo san lucas
# Processing Record 24 of Set 8 | galle
# Processing Record 25 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 8 | erdenet
# Processing Record 27 of Set 8 | bandarbeyla
# Processing Record 28 of Set 8 | santa lucia
# Processing Record 29 of Set 8 | zalantun
# Processing Record 30 of Set 8 | roald
# Processing Record 31 of Set 8 | sertanopolis
# Processing Record 32 of Set 8 | jieshou
# Processing Record 33 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 34 of Set 8 | miraflores
# Processing Record 35 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 8 | port hardy
# Processing Record 37 of Set 8 | teahupoo
# Processing Record 38 of Set 8 | conde
# Processing Record 39 of Set 8 | la rochelle
# Processing Record 40 of Set 8 | beira
# Processing Record 41 of Set 8 | monthey
# Processing Record 42 of Set 8 | san cristobal
# Processing Record 43 of Set 8 | dubbo
# Processing Record 44 of Set 8 | mulchen
# Processing Record 45 of Set 8 | maltahohe
# Processing Record 46 of Set 8 | tahta
# Processing Record 47 of Set 8 | kulhudhuffushi
# Processing Record 48 of Set 8 | ciocanesti
# Processing Record 49 of Set 8 | ishigaki
# Processing Record 50 of Set 8 | kamenka
# Processing Record 1 of Set 9 | figline valdarno
# Processing Record 2 of Set 9 | mercedes
# Processing Record 3 of Set 9 | formiga
# Processing Record 4 of Set 9 | san antonio
# Processing Record 5 of Set 9 | coroata
# Processing Record 6 of Set 9 | monterey
# Processing Record 7 of Set 9 | sug-aksy
# City not found. Skipping...
# Processing Record 8 of Set 9 | inirida
# Processing Record 9 of Set 9 | san luis
# Processing Record 10 of Set 9 | bengkulu
# Processing Record 11 of Set 9 | beitbridge
# Processing Record 12 of Set 9 | hay river
# Processing Record 13 of Set 9 | mpika
# Processing Record 14 of Set 9 | sretensk
# Processing Record 15 of Set 9 | newport
# Processing Record 16 of Set 9 | goundam
# Processing Record 17 of Set 9 | bilokurakyne
# Processing Record 18 of Set 9 | uyuni
# Processing Record 19 of Set 9 | palmer
# Processing Record 20 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 9 | mairi
# Processing Record 22 of Set 9 | ajdovscina
# Processing Record 23 of Set 9 | marrakesh
# Processing Record 24 of Set 9 | sakakah
# Processing Record 25 of Set 9 | russell
# Processing Record 26 of Set 9 | atar
# Processing Record 27 of Set 9 | mvuma
# Processing Record 28 of Set 9 | mogadishu
# Processing Record 29 of Set 9 | richmond
# Processing Record 30 of Set 9 | la palma
# Processing Record 31 of Set 9 | nicoya
# Processing Record 32 of Set 9 | chuy
# Processing Record 33 of Set 9 | dieppe
# Processing Record 34 of Set 9 | ballymena
# Processing Record 35 of Set 9 | mugumu
# Processing Record 36 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 9 | maneadero
# Processing Record 38 of Set 9 | otane
# Processing Record 39 of Set 9 | saint george
# Processing Record 40 of Set 9 | nicolas bravo
# Processing Record 41 of Set 9 | lakota
# Processing Record 42 of Set 9 | tecoanapa
# Processing Record 43 of Set 9 | sanski most
# Processing Record 44 of Set 9 | naron
# Processing Record 45 of Set 9 | masterton
# Processing Record 46 of Set 9 | markova
# Processing Record 47 of Set 9 | sena madureira
# Processing Record 48 of Set 9 | jining
# Processing Record 49 of Set 9 | sao filipe
# Processing Record 50 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 1 of Set 10 | boissevain
# Processing Record 2 of Set 10 | iskateley
# Processing Record 3 of Set 10 | bentiu
# Processing Record 4 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 10 | hurghada
# Processing Record 6 of Set 10 | jackson
# Processing Record 7 of Set 10 | vallenar
# Processing Record 8 of Set 10 | portland
# Processing Record 9 of Set 10 | coihaique
# Processing Record 10 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 10 | krasnoborsk
# Processing Record 12 of Set 10 | ust-omchug
# Processing Record 13 of Set 10 | duz
# City not found. Skipping...
# Processing Record 14 of Set 10 | mitu
# Processing Record 15 of Set 10 | ahipara
# Processing Record 16 of Set 10 | harper
# Processing Record 17 of Set 10 | lidorikion
# City not found. Skipping...
# Processing Record 18 of Set 10 | lakselv
# Processing Record 19 of Set 10 | bangassou
# Processing Record 20 of Set 10 | los llanos de aridane
# Processing Record 21 of Set 10 | laguna
# Processing Record 22 of Set 10 | haines junction
# Processing Record 23 of Set 10 | takayama
# Processing Record 24 of Set 10 | bouza
# Processing Record 25 of Set 10 | alyangula
# Processing Record 26 of Set 10 | totness
# Processing Record 27 of Set 10 | mount gambier
# Processing Record 28 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 10 | quartucciu
# Processing Record 30 of Set 10 | robertsport
# Processing Record 31 of Set 10 | arman
# Processing Record 32 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 33 of Set 10 | martapura
# Processing Record 34 of Set 10 | sarany
# Processing Record 35 of Set 10 | porlamar
# Processing Record 36 of Set 10 | belmonte
# Processing Record 37 of Set 10 | itarema
# Processing Record 38 of Set 10 | papetoai
# Processing Record 39 of Set 10 | chapais
# Processing Record 40 of Set 10 | jodhpur
# Processing Record 41 of Set 10 | vila franca do campo
# Processing Record 42 of Set 10 | lingao
# Processing Record 43 of Set 10 | kendari
# Processing Record 44 of Set 10 | beipiao
# Processing Record 45 of Set 10 | dongsheng
# Processing Record 46 of Set 10 | koryukivka
# Processing Record 47 of Set 10 | ahuas
# Processing Record 48 of Set 10 | kanungu
# Processing Record 49 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 10 | shingu
# Processing Record 1 of Set 11 | abu zabad
# Processing Record 2 of Set 11 | najran
# Processing Record 3 of Set 11 | barra do garcas
# Processing Record 4 of Set 11 | siteki
# Processing Record 5 of Set 11 | amol
# Processing Record 6 of Set 11 | tchibanga
# Processing Record 7 of Set 11 | ponte de sor
# Processing Record 8 of Set 11 | omsukchan
# Processing Record 9 of Set 11 | plastun
# Processing Record 10 of Set 11 | padang
# Processing Record 11 of Set 11 | marawi
# Processing Record 12 of Set 11 | boralday
# Processing Record 13 of Set 11 | milledgeville
# Processing Record 14 of Set 11 | biltine
# Processing Record 15 of Set 11 | zhigansk
# Processing Record 16 of Set 11 | reconquista
# Processing Record 17 of Set 11 | upington
# Processing Record 18 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 11 | atasu
# Processing Record 20 of Set 11 | sao joao da barra
# Processing Record 21 of Set 11 | sauda
# Processing Record 22 of Set 11 | oistins
# Processing Record 23 of Set 11 | grand-santi
# Processing Record 24 of Set 11 | husainabad
# Processing Record 25 of Set 11 | ratnagiri
# Processing Record 26 of Set 11 | hailar
# Processing Record 27 of Set 11 | port hedland
# Processing Record 28 of Set 11 | manerbio
# Processing Record 29 of Set 11 | luau
# Processing Record 30 of Set 11 | yamada
# Processing Record 31 of Set 11 | aguas vermelhas
# Processing Record 32 of Set 11 | nuuk
# Processing Record 33 of Set 11 | mecca
# Processing Record 34 of Set 11 | deogarh
# Processing Record 35 of Set 11 | broome
# Processing Record 36 of Set 11 | bacolod
# Processing Record 37 of Set 11 | zitsa
# Processing Record 38 of Set 11 | kichera
# Processing Record 39 of Set 11 | gairo
# Processing Record 40 of Set 11 | pacific grove
# Processing Record 41 of Set 11 | cairns
# Processing Record 42 of Set 11 | benguela
# Processing Record 43 of Set 11 | lorengau
# Processing Record 44 of Set 11 | chumikan
# Processing Record 45 of Set 11 | avera
# Processing Record 46 of Set 11 | cayenne
# Processing Record 47 of Set 11 | kodinsk
# Processing Record 48 of Set 11 | palwal
# Processing Record 49 of Set 11 | birjand
# Processing Record 50 of Set 11 | ilorin
# Processing Record 1 of Set 12 | doha
# Processing Record 2 of Set 12 | kyshtovka
# Processing Record 3 of Set 12 | ulladulla
# Processing Record 4 of Set 12 | moroto
# Processing Record 5 of Set 12 | fare
# Processing Record 6 of Set 12 | lyngseidet
# Processing Record 7 of Set 12 | la ronge
# Processing Record 8 of Set 12 | pontianak
# Processing Record 9 of Set 12 | sur
# Processing Record 10 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 12 | sisimiut
# Processing Record 12 of Set 12 | neuquen
# Processing Record 13 of Set 12 | kaman
# Processing Record 14 of Set 12 | san roque
# Processing Record 15 of Set 12 | selenduma
# Processing Record 16 of Set 12 | bonthe
# Processing Record 17 of Set 12 | berlevag
# Processing Record 18 of Set 12 | oume
# Processing Record 19 of Set 12 | nakamura
# Processing Record 20 of Set 12 | key biscayne
# Processing Record 21 of Set 12 | west bay
# Processing Record 22 of Set 12 | tessalit
# Processing Record 23 of Set 12 | daru
# Processing Record 24 of Set 12 | rio gallegos
# Processing Record 25 of Set 12 | manavalakurichi
# Processing Record 26 of Set 12 | riohacha
# Processing Record 27 of Set 12 | urumqi
# Processing Record 28 of Set 12 | flin flon
# Processing Record 29 of Set 12 | molepolole
# Processing Record 30 of Set 12 | balkhash
# Processing Record 31 of Set 12 | dumas
# Processing Record 32 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 33 of Set 12 | coquimbo
# Processing Record 34 of Set 12 | panzhihua
# Processing Record 35 of Set 12 | karistos
# City not found. Skipping...
# Processing Record 36 of Set 12 | honiara
# Processing Record 37 of Set 12 | vao
# Processing Record 38 of Set 12 | vyshchetarasivka
# Processing Record 39 of Set 12 | dyatkovo
# Processing Record 40 of Set 12 | flinders
# Processing Record 41 of Set 12 | caconda
# Processing Record 42 of Set 12 | weihai
# Processing Record 43 of Set 12 | weligama
# Processing Record 44 of Set 12 | naryan-mar
# Processing Record 45 of Set 12 | chongwe
# Processing Record 46 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 12 | midland
# Processing Record 48 of Set 12 | arlit
# Processing Record 49 of Set 12 | kastamonu
# Processing Record 50 of Set 12 | prince rupert
# Processing Record 1 of Set 13 | siocon
# Processing Record 2 of Set 13 | salgueiro
# Processing Record 3 of Set 13 | iquitos
# Processing Record 4 of Set 13 | melekhovskaya
# City not found. Skipping...
# Processing Record 5 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 13 | coari
# Processing Record 7 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 13 | urucara
# Processing Record 9 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 10 of Set 13 | asilah
# Processing Record 11 of Set 13 | impfondo
# Processing Record 12 of Set 13 | kentau
# Processing Record 13 of Set 13 | talawdi
# City not found. Skipping...
# Processing Record 14 of Set 13 | qeshm
# Processing Record 15 of Set 13 | marechal floriano
# Processing Record 16 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 17 of Set 13 | aklavik
# Processing Record 18 of Set 13 | astana
# Processing Record 19 of Set 13 | puerto pinasco
# City not found. Skipping...
# Processing Record 20 of Set 13 | quixeramobim
# Processing Record 21 of Set 13 | dauphin
# Processing Record 22 of Set 13 | tomatlan
# Processing Record 23 of Set 13 | uruzgan
# Processing Record 24 of Set 13 | axim
# Processing Record 25 of Set 13 | taywarah
# Processing Record 26 of Set 13 | gamut
# Processing Record 27 of Set 13 | la plata
# Processing Record 28 of Set 13 | ketchikan
# Processing Record 29 of Set 13 | vanimo
# Processing Record 30 of Set 13 | marquette
# Processing Record 31 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 13 | hannibal
# Processing Record 33 of Set 13 | colac
# Processing Record 34 of Set 13 | spruce grove
# Processing Record 35 of Set 13 | teya
# Processing Record 36 of Set 13 | fairbanks
# Processing Record 37 of Set 13 | northeim
# Processing Record 38 of Set 13 | conselice
# Processing Record 39 of Set 13 | charters towers
# Processing Record 40 of Set 13 | lata
# Processing Record 41 of Set 13 | rawah
# Processing Record 42 of Set 13 | ondjiva
# Processing Record 43 of Set 13 | lagos
# Processing Record 44 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 13 | bassano
# Processing Record 46 of Set 13 | boyolangu
# Processing Record 47 of Set 13 | sitges
# Processing Record 48 of Set 13 | kysyl-syr
# Processing Record 49 of Set 13 | boa vista
# Processing Record 50 of Set 13 | risor
# Processing Record 1 of Set 14 | chicama
# Processing Record 2 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 3 of Set 14 | zhangjiakou
# Processing Record 4 of Set 14 | mega
# Processing Record 5 of Set 14 | high prairie
# Processing Record 6 of Set 14 | udachnyy
# Processing Record 7 of Set 14 | jardim
# Processing Record 8 of Set 14 | tha muang
# Processing Record 9 of Set 14 | saint-augustin
# Processing Record 10 of Set 14 | luganville
# Processing Record 11 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 12 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 13 of Set 14 | la ligua
# Processing Record 14 of Set 14 | malakal
# Processing Record 15 of Set 14 | ambon
# Processing Record 16 of Set 14 | bac lieu
# Processing Record 17 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 14 | okhotsk
# Processing Record 19 of Set 14 | kota kinabalu
# Processing Record 20 of Set 14 | ligayan
# Processing Record 21 of Set 14 | ust-nera
# Processing Record 22 of Set 14 | pilar
# Processing Record 23 of Set 14 | fuxin
# Processing Record 24 of Set 14 | kampot
# Processing Record 25 of Set 14 | huangnihe
# Processing Record 26 of Set 14 | mehran
# Processing Record 27 of Set 14 | vallejo
# Processing Record 28 of Set 14 | ambilobe
# Processing Record 29 of Set 14 | bowen
# Processing Record 30 of Set 14 | majene
# Processing Record 31 of Set 14 | bogorodskoye
# Processing Record 32 of Set 14 | nokaneng
# Processing Record 33 of Set 14 | murchison
# Processing Record 34 of Set 14 | coihueco
# Processing Record 35 of Set 14 | everett
# Processing Record 36 of Set 14 | backa palanka
# Processing Record 37 of Set 14 | whitehorse
# Processing Record 38 of Set 14 | yakeshi
# Processing Record 39 of Set 14 | loa janan
# Processing Record 40 of Set 14 | buenos aires
# Processing Record 41 of Set 14 | fantino
# Processing Record 42 of Set 14 | zanjan
# Processing Record 43 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 14 | piacabucu
# Processing Record 45 of Set 14 | lishui
# Processing Record 46 of Set 14 | mbaiki
# Processing Record 47 of Set 14 | slave lake
# Processing Record 48 of Set 14 | palmas
# Processing Record 49 of Set 14 | kieta
# Processing Record 50 of Set 14 | tomigusuku
# Processing Record 1 of Set 15 | kalabo
# Processing Record 2 of Set 15 | nyurba
# Processing Record 3 of Set 15 | fukue
# Processing Record 4 of Set 15 | kiunga
# Processing Record 5 of Set 15 | gerash
# Processing Record 6 of Set 15 | te anau
# Processing Record 7 of Set 15 | mandalgarh
# Processing Record 8 of Set 15 | acarau
# Processing Record 9 of Set 15 | curup
# Processing Record 10 of Set 15 | biryusinsk
# Processing Record 11 of Set 15 | khandbari
# Processing Record 12 of Set 15 | kindu
# Processing Record 13 of Set 15 | ugoofaaru
# Processing Record 14 of Set 15 | verkhoyansk
# Processing Record 15 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 15 | timmins
# Processing Record 17 of Set 15 | kinanah
# City not found. Skipping...
# Processing Record 18 of Set 15 | dalbandin
# Processing Record 19 of Set 15 | marsabit
# Processing Record 20 of Set 15 | saedinenie
# Processing Record 21 of Set 15 | sawtell
# Processing Record 22 of Set 15 | pemberton
# Processing Record 23 of Set 15 | nata
# Processing Record 24 of Set 15 | venice
# Processing Record 25 of Set 15 | wanning
# Processing Record 26 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 15 | saurimo
# Processing Record 28 of Set 15 | datong
# Processing Record 29 of Set 15 | shache
# Processing Record 30 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 15 | ahuimanu
# Processing Record 32 of Set 15 | griffith
# Processing Record 33 of Set 15 | bintulu
# Processing Record 34 of Set 15 | novaya igirma
# Processing Record 35 of Set 15 | santiago
# Processing Record 36 of Set 15 | kanniyakumari
# Processing Record 37 of Set 15 | itaueira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Tuatapere      NZ -46.1333  167.6833     53.82        83
# 1              Dikson      RU  73.5069   80.5464     -4.49        91
# 2      Saint-Philippe      RE -21.3585   55.7679     83.79        79
# 3      Severo-Kurilsk      RU  50.6789  156.1250     20.75        70
# 4           Cape Town      ZA -33.9258   18.4232     74.88        76
# 5              Hobart      AU -42.8794  147.3294     78.22        49
# 6      Ribeira Grande      PT  38.5167  -28.7000     60.91        85
# 7  Comodoro Rivadavia      AR -45.8667  -67.5000     58.86        67
# 8        Saint-Pierre      RE -21.3393   55.4781     83.88        70
# 9             Qaanaaq      GL  77.4840  -69.3632    -15.66        47
#
#    Cloudiness  Wind Speed Current Description
# 0          99        2.04     overcast clouds
# 1         100       25.28     overcast clouds
# 2         100       13.67          light rain
# 3          19        3.87          few clouds
# 4           0       17.27           clear sky
# 5          75       16.11       broken clouds
# 6         100       15.28     overcast clouds
# 7           0        4.61           clear sky
# 8           0        9.22           clear sky
# 9           2        9.80           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
